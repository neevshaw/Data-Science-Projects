# %%
dbda_programs = "../DBDA2Eprograms/"
src = function(name) {
    source(paste0(dbda_programs, name, ".R"))
}

# %%
src("DBDA2E-utilities")  # Load definitions of graphics functions etc.
src("BernBeta")          # Load the definition of the BernBeta function
# Out:
# *********************************************************************
# Kruschke, J. K. (2015). Doing Bayesian Data Analysis, Second Edition:
# A Tutorial with R, JAGS, and Stan. Academic Press / Elsevier.
# *********************************************************************

# %%
curve(dbeta(x, 17, 3))
# Out:
# plot without title

# %%
curve(dbeta(x, 1, 1))
# Out:
# plot without title

# %%
curve(dbeta(x, 10,10))
# Out:
# plot without title

# %%
t = 0.001             # Specify the prior MODE.
n = 10000               # Specify the effective prior sample size.
a = t*(n-2) + 1      # Convert to beta shape parameter a.
b = (1-t)*(n-2) + 1  # Convert to beta shape parameter b.

Prior = c(a,b)       # Specify Prior as vector with the two shape parameters.

# Specify the data:
N = 968167                         # The total number of flips.
z = 273                         # The number of heads.
Data = c(rep(0,N-z),rep(1,z))  # Convert N and z into vector of 0's and 1's.

posterior = BernBeta( priorBetaAB=Prior, Data=Data , plotType="Bars" , 
                      showCentTend="Mode" , showHDI=TRUE , showpD=F )
# Out:
# [1] 0.0002568988 0.0003243494
# Plot with title "Posterior (beta)"

# %%
t = 0.001             # Specify the prior MODE.
n = 10000               # Specify the effective prior sample size.
a = t*(n-2) + 1      # Convert to beta shape parameter a.
b = (1-t)*(n-2) + 1  # Convert to beta shape parameter b.

Prior = c(a,b)       # Specify Prior as vector with the two shape parameters.

# Specify the data:
N = 15484235                         # The total number of flips.
z = 10737                         # The number of heads.
Data = c(rep(0,N-z),rep(1,z))  # Convert N and z into vector of 0's and 1's.

posterior = BernBeta( priorBetaAB=Prior, Data=Data , plotType="Bars" , 
                      showCentTend="Mode" , showHDI=TRUE , showpD=F )
# Out:
# [1] 0.0006805860 0.0007068046
# Plot with title "Posterior (beta)"

# %%
t = 0.001             # Specify the prior MODE.
n = 10000               # Specify the effective prior sample size.
a = t*(n-2) + 1      # Convert to beta shape parameter a.
b = (1-t)*(n-2) + 1  # Convert to beta shape parameter b.

Prior = c(a,b)       # Specify Prior as vector with the two shape parameters.

# Specify the data:
N = 1370782                         # The total number of flips.
z = 378                         # The number of heads.
Data = c(rep(0,N-z),rep(1,z))  # Convert N and z into vector of 0's and 1's.

posterior = BernBeta( priorBetaAB=Prior, Data=Data , plotType="Bars" , 
                      showCentTend="Mode" , showHDI=TRUE , showpD=F )
# Out:
# [1] 0.0002539565 0.0003098961
# Plot with title "Posterior (beta)"

# %%
t = 0.001             # Specify the prior MODE.
n = 10000               # Specify the effective prior sample size.
a = t*(n-2) + 1      # Convert to beta shape parameter a.
b = (1-t)*(n-2) + 1  # Convert to beta shape parameter b.

Prior = c(a,b)       # Specify Prior as vector with the two shape parameters.

# Specify the data:
N = 3911146                         # The total number of flips.
z = 44789                         # The number of heads.
Data = c(rep(0,N-z),rep(1,z))  # Convert N and z into vector of 0's and 1's.

posterior = BernBeta( priorBetaAB=Prior, Data=Data , plotType="Bars" , 
                      showCentTend="Mode" , showHDI=TRUE , showpD=F )
# Out:
# [1] 0.01132011 0.01153049
# Plot with title "Posterior (beta)"

# %% [markdown]
# People with no previous diagnosis are twice as likely to get hospitalized if they have not taken the vaccine. Those with a previous diagnosis (and thus with natural immunity) have overlapping high-density intervals for rate of hospitalization for the vaccinated and unvaccinated cohorts.
