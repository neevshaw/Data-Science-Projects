# %% [markdown]
# # 1. JAGS Installation

# %% [markdown]
# $\checkmark$ Complete!

# %% [markdown]
# # 2. DBDA Exercises

# %% [markdown]
# ## Exercise 2.1

# %% [markdown]
# ### Model A:

# %% [markdown]
# \begin{align}
# p(1) &= \dfrac14 \\
# p(2) &= \dfrac14 \\
# p(3) &= \dfrac14 \\
# p(4) &= \dfrac14 \\
# \end{align}

# %% [markdown]
# ### Model B:

# %% [markdown]
# \begin{align}
# p(1) &= \dfrac1{10} \\
# p(2) &= \dfrac2{10} \\
# p(3) &= \dfrac3{10} \\
# p(4) &= \dfrac4{10} \\
# \end{align}
